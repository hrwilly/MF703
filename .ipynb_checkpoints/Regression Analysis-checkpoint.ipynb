# %%
import pandas as pd
from finance_byu import fama_macbeth
import numpy as np
import warnings
warnings.filterwarnings("ignore")

# %%
def fama(data, control):

    comb = []
    tickers = data.columns

    for i in range(len(tickers)):
        data[tickers[i]].index = pd.to_datetime(data[tickers[i]].index)
        combined = pd.concat([data[tickers[i]].rename('future'), control[i]], axis = 1)

        comb.append(combined)

    for i in range(len(comb)):
        comb[i] = comb[i].reset_index()
        comb[i]['Unnamed: 0'] = pd.to_datetime(pd.to_datetime(comb[i]['Unnamed: 0']).dt.strftime('%Y-%m'))

    results = []
    tickers = data.columns        

    for i in range(len(comb)):
        xvar = []
        comb[i] = comb[i].dropna(axis = 1, how = 'all')
        comb[i] = comb[i].dropna(axis = 0, how = 'any')
        for j in range(2, len(comb[i].columns)):
            xvar.append(comb[i].columns[j])
        comb[i] = comb[i].dropna(axis = 1, how = 'all')
        comb[i] = comb[i].dropna(axis = 0, how = 'any')
        results.append(fama_macbeth.fama_macbeth_master(comb[i], t = 'Unnamed: 0', yvar = 'future', xvar = xvar, intercept=True))

    return results

# %%
ret = pd.read_csv('Final Variables/monthly_returns.csv')
abpr = pd.read_csv('Final Variables/abnormal_positive_ratio.csv')
abnr = pd.read_csv('Final Variables/abnormal_negative_ratio.csv')
ret_co_m = pd.read_csv('variable_results/sp500/filtered_ret_co_m.csv')
ret_oc_m = pd.read_csv('variable_results/sp500/filtered_ret_oc_m.csv')
size = pd.read_csv('Final Variables/monthly_size.csv')
bm = pd.read_csv('variable_results/sp500/log_monthly_bm.csv')
ret_6m = pd.read_csv('Final Variables/monthly_cum_sum.csv')
gpa = pd.read_csv('Final Variables/annual_gross_profit.csv')
atgth = pd.read_csv('variable_results/sp500/filtered_monthly_asset_growth.csv')
turn_m = pd.read_csv('variable_results/sp500/log_monthly_turnover.csv')
illiq_m = pd.read_csv('variable_results/sp500/filtered_illiquidity.csv')

def correct_format(var):
    var['Unnamed: 0'] = pd.to_datetime(pd.to_datetime(var['Unnamed: 0']).dt.strftime('%Y-%m'))
    var = var.set_index('Unnamed: 0')
    var = var.reindex(sorted(var.columns), axis=1)
    return var

ret = correct_format(ret)
abpr = correct_format(abpr)
abnr = correct_format(abnr)
ret_co_m = correct_format(ret_co_m)
ret_oc_m = correct_format(ret_oc_m)
size = correct_format(size)
size = np.log(size)
bm = correct_format(bm)
ret_6m = correct_format(ret_6m)
gpa = correct_format(gpa)
atgth = atgth.rename(columns = {'Date' : 'Unnamed: 0'})
atgth = correct_format(atgth)
turn_m = turn_m.rename(columns = {'Date' : 'Unnamed: 0'})
turn_m = correct_format(turn_m)
illiq_m = illiq_m.rename(columns = {'index' : 'Unnamed: 0'})
illiq_m = correct_format(illiq_m)['2014-01-01' : '2022-12-13']

for i in range(len(turn_m['MTCH'])):
    if turn_m['MTCH'][i] == '--':
        turn_m['MTCH'][i] = np.float64('nan')
    else:
        turn_m['MTCH'][i] = np.log(np.float64(turn_m['MTCH'][i]))
turn_m['MTCH'] = turn_m['MTCH'].astype(float)
for i in range(len(turn_m['WBD'])):
    if turn_m['WBD'][i] == '--':
        turn_m['WBD'][i] = np.float64('nan')
    else:
        turn_m['WBD'][i] = np.log(np.float64(turn_m['WBD'][i]))
turn_m['WBD'] = turn_m['WBD'].astype(float)

dep = ret.shift(-1)

controls1 = []
controls2 = []
controls3 = []
controls4 = []
controls5 = []

for ticker in ret_co_m:
    data1 = pd.DataFrame()
    data1['ABNR'] = abnr[ticker]
    data1['ABPR'] = abpr[ticker]
    data1['close to open'] = ret_co_m[ticker]
    data1['open to close'] = ret_oc_m[ticker]
    controls1.append(data1)
    data2 = pd.DataFrame()
    data2['size'] = size[ticker]
    data2['bm'] = bm[ticker]
    data2['ret_6m'] = ret_6m[ticker]
    data2 = pd.concat([data1, data2], axis = 1)
    controls2.append(data2)
    data3 = pd.DataFrame()
    data3['gpa'] = gpa[ticker]
    data3['atgth'] = atgth[ticker]
    data3 = pd.concat([data2, data3], axis = 1)
    controls3.append(data3)
    data4 = pd.DataFrame()
    data4['turn_m'] = turn_m[ticker]
    data4['illiq_m'] = illiq_m[ticker]
    data4 = pd.concat([data3, data4], axis = 1)
    controls4.append(data4)
    data5 = data4.drop(['ABNR', 'ABPR'], axis = 1)
    controls5.append(data5)

# %%
reg1 = fama(dep, controls1)
reg2 = fama(dep, controls2)
reg3 = fama(dep, controls3)
reg4 = fama(dep, controls4)
reg5 = fama(dep, controls5)

# %%
alpha = []
ABNR = []
ABPR = []
RET_CO_M = []
RET_OC_M = []

for i in range(len(reg1)):
    alpha.append(reg1[i]['intercept'])
    ABNR.append(reg1[i]['ABNR'])
    ABPR.append(reg1[i]['ABPR'])
    RET_CO_M.append(reg1[i]['close to open'])
    RET_OC_M.append(reg1[i]['open to close'])

d = {'Intercept' : alpha, 'ABNR' : ABNR, 'ABPR' : ABPR, 
     'RET_CO_M' : RET_CO_M, 'RET_OC_M' : RET_OC_M}

result1 = np.mean(pd.DataFrame(data = d))

alpha = []
ABNR = []
ABPR = []
RET_CO_M = []
RET_OC_M = []
size = []
bm = []
ret_6m = []

for i in range(len(reg2)):
    alpha.append(reg2[i]['intercept'])
    ABNR.append(reg2[i]['ABNR'])
    ABPR.append(reg2[i]['ABPR'])
    RET_CO_M.append(reg2[i]['close to open'])
    RET_OC_M.append(reg2[i]['open to close'])
    size.append(reg2[i]['size'])
    if 'bm' in reg2[i].columns:
        bm.append(reg2[i]['bm'])
    ret_6m.append(reg2[i]['ret_6m'])

fac = len(alpha) - len(bm)
for i in range(fac):
    bm.append(np.float64('nan'))

d = {'Intercept' : alpha, 'ABNR' : ABNR, 'ABPR' : ABPR, 'RET_CO_M' : RET_CO_M, 
     'RET_OC_M' : RET_OC_M, 'SIZE' : size, 'BM' : bm, 'RET_6M' : ret_6m}

result2 = np.mean(pd.DataFrame(data = d))

alpha = []
ABNR = []
ABPR = []
RET_CO_M = []
RET_OC_M = []
size = []
bm = []
ret_6m = []
gpa = []
atgth = []

for i in range(len(reg3)):
    alpha.append(reg3[i]['intercept'])
    ABNR.append(reg3[i]['ABNR'])
    ABPR.append(reg3[i]['ABPR'])
    RET_CO_M.append(reg3[i]['close to open'])
    RET_OC_M.append(reg3[i]['open to close'])
    size.append(reg3[i]['size'])
    if 'bm' in reg3[i].columns:
        bm.append(reg3[i]['bm'])
    ret_6m.append(reg3[i]['ret_6m'])
    gpa.append(reg3[i]['gpa'])
    atgth.append(reg3[i]['atgth'])

fac = len(alpha) - len(bm)
for i in range(fac):
    bm.append(np.float64('nan'))

d = {'Intercept' : alpha, 'ABNR' : ABNR, 'ABPR' : ABPR, 'RET_CO_M' : RET_CO_M, 'RET_OC_M' : RET_OC_M, 
     'SIZE' : size, 'BM' : bm, 'RET_6M' : ret_6m, 'GPA' : gpa, 'ATGTH' : atgth}

result3 = np.mean(pd.DataFrame(data = d))

alpha = []
ABNR = []
ABPR = []
RET_CO_M = []
RET_OC_M = []
size = []
bm = []
ret_6m = []
gpa = []
atgth = []
turn_m = []
illiq_m = []

for i in range(len(reg4)):
    alpha.append(reg4[i]['intercept'])
    ABNR.append(reg4[i]['ABNR'])
    ABPR.append(reg4[i]['ABPR'])
    RET_CO_M.append(reg4[i]['close to open'])
    RET_OC_M.append(reg4[i]['open to close'])
    size.append(reg4[i]['size'])
    if 'bm' in reg4[i].columns:
        bm.append(reg4[i]['bm'])
    ret_6m.append(reg4[i]['ret_6m'])
    gpa.append(reg4[i]['gpa'])
    atgth.append(reg4[i]['atgth'])
    turn_m.append(reg4[i]['turn_m'])
    illiq_m.append(reg4[i]['illiq_m'])

fac = len(alpha) - len(bm)
for i in range(fac):
    bm.append(np.float64('nan'))

d = {'Intercept' : alpha, 'ABNR' : ABNR, 'ABPR' : ABPR, 'RET_CO_M' : RET_CO_M, 'RET_OC_M' : RET_OC_M,  'SIZE' : size, 
     'BM' : bm, 'RET_6M' : ret_6m, 'GPA' : gpa, 'ATGTH' : atgth, 'TURN_M' : turn_m, 'ILLIQ_M' : illiq_m}

result4 = np.mean(pd.DataFrame(data = d))

alpha = []
RET_CO_M = []
RET_OC_M = []
size = []
bm = []
ret_6m = []
gpa = []
atgth = []
turn_m = []
illiq_m = []

for i in range(len(reg5)):
    alpha.append(reg5[i]['intercept'])
    RET_CO_M.append(reg5[i]['close to open'])
    RET_OC_M.append(reg5[i]['open to close'])
    size.append(reg5[i]['size'])
    if 'bm' in reg5[i].columns:
        bm.append(reg5[i]['bm'])
    ret_6m.append(reg5[i]['ret_6m'])
    gpa.append(reg5[i]['gpa'])
    atgth.append(reg5[i]['atgth'])
    turn_m.append(reg5[i]['turn_m'])
    illiq_m.append(reg5[i]['illiq_m'])

fac = len(alpha) - len(bm)
for i in range(fac):
    bm.append(np.float64('nan'))

d = {'Intercept' : alpha, 'RET_CO_M' : RET_CO_M, 'RET_OC_M' : RET_OC_M,  'SIZE' : size, 'BM' : bm, 
     'RET_6M' : ret_6m, 'GPA' : gpa, 'ATGTH' : atgth, 'TURN_M' : turn_m, 'ILLIQ_M' : illiq_m}

result5 = np.mean(pd.DataFrame(data = d))

# %%
final = pd.concat([result1.rename('RET(1)'), result2.rename('RET(1)'), result3.rename('RET(1)'), 
                   result4.rename('RET(1)'), result5.rename('RET(1)')], axis = 1)
final = final.replace(np.nan, '')
final.to_csv('Regression/reg_results.csv')

# %%
final
# Out:
#              RET(1)    RET(1)    RET(1)      RET(1)      RET(1)
# Intercept  0.016022  0.072075  0.069775    0.145067    0.095591
# ABNR      -0.139262 -0.163552 -0.154541   -0.154290
# ABPR       0.072361  0.076068  0.048799    0.056069
# RET_CO_M  -0.209519 -0.249065 -0.266796   -0.278092    -0.26229
# RET_OC_M  -0.037309 -0.064183 -0.069942   -0.073965     -0.0935
# SIZE                 -0.00024  0.000385   -0.002416   -0.001508
# BM                  -0.251106 -0.309358   -0.297865   -0.307181
# RET_6M               -0.14019 -0.194928   -0.193591   -0.180988
# GPA                            0.048799    0.056069    0.136111
# ATGTH                         -0.014257   -0.000054    -0.00383
# TURN_M                                    -0.000243    0.000712
# ILLIQ_M                                  446.692200  364.158187
